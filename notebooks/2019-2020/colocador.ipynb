# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=59&PID=92'
parametro='estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
    
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Acciones_exitosas', 'Errores_colocador',
                '_error_colocador', 'Puntos_negativos', 'Puntos_positivos',
                'Acciones_positivas', 'Total_acumulado', 'Efic_Ranking',2]

parametro= 'estadistica_colocador'
colocador = crear_df(datos[5],columna,parametro)
colocador.drop([1,2], inplace=True, axis=1)
colocador.reset_index(inplace=True)
colocador.head(2)
# Out:
#    index                     Nombre Partidos_jugados Sets_jugados  \
# 0      0             Pei-Hung Huang                7           16
# 1      1  Jukoski Da Silva Pedro H.               18           54
#
#   Acciones_exitosas Errores_colocador _error_colocador Puntos_negativos  \
# 0                79                 0                8               15
# 1               287                 3               16               72
#
#   Puntos_positivos Acciones_positivas Total_acumulado Efic_Ranking
# 0               29                  6             137       0,4234
# 1               45                 33             456       0,3991

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2019-2020/jugadores.csv')
df.head(2)
# Out:
#    Dorsal               Nombre        Posición  Altura  Año_de_nacimiento  \
# 0       1  García Taibo Javier        Receptor   200.0               2000
# 1       2  Linares Palmas Luis  Middle-blocker   197.0               1995
#
#    Alcance_en_ataque  Alcance_en_bloqueo   id_jugador  temporada    id_equipo
# 0              330.0               316.0  1-2019-2020  2019-2020  1-2019-2020
# 1              340.0               330.0  2-2019-2020  2019-2020  1-2019-2020

# %%
colocador = pd.merge(colocador, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')

colocador.head()
# Out:
#    index                     Nombre Partidos_jugados Sets_jugados  \
# 0      0             Pei-Hung Huang                7           16
# 1      1  Jukoski Da Silva Pedro H.               18           54
# 2      2     Perini de Aviz Ricardo               16           55
# 3      3     Soteldo Francisco José               16           56
# 4      4         Martín Pérez César               17           54
#
#   Acciones_exitosas Errores_colocador _error_colocador Puntos_negativos  \
# 0                79                 0                8               15
# 1               287                 3               16               72
# 2               329                 0               48               67
# 3               275                 1               45               59
# 4               149                 0               11               47
#
#   Puntos_positivos Acciones_positivas Total_acumulado Efic_Ranking  \
# 0               29                  6             137       0,4234
# 1               45                 33             456       0,3991
# 2              110                 37             591       0,3807
# 3               62                 37             479       0,3737
# 4               27                 18             252       0,3333
#
#       id_jugador     id_equipo
# 0   95-2019-2020   7-2019-2020
# 1   16-2019-2020   2-2019-2020
# 2   98-2019-2020   8-2019-2020
# 3  154-2019-2020  12-2019-2020
# 4   18-2019-2020   2-2019-2020

# %%
colocador['temporada']='2019-2020'
colocador.drop(['index'], axis=1, inplace=True)
colocador.head(2)
# Out:
#                       Nombre Partidos_jugados Sets_jugados Acciones_exitosas  \
# 0             Pei-Hung Huang                7           16                79
# 1  Jukoski Da Silva Pedro H.               18           54               287
#
#   Errores_colocador _error_colocador Puntos_negativos Puntos_positivos  \
# 0                 0                8               15               29
# 1                 3               16               72               45
#
#   Acciones_positivas Total_acumulado Efic_Ranking    id_jugador    id_equipo  \
# 0                  6             137       0,4234  95-2019-2020  7-2019-2020
# 1                 33             456       0,3991  16-2019-2020  2-2019-2020
#
#    temporada
# 0  2019-2020
# 1  2019-2020

# %%
convertir = colocador.columns.difference(['Nombre'])
colocador['Efic_Ranking'] = colocador['Efic_Ranking'].str.replace(',', '.').astype(float)
colocador[convertir] = colocador[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)

colocador.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nombre              21 non-null     object
#  1   Partidos_jugados    21 non-null     int64
#  2   Sets_jugados        21 non-null     int64
#  3   Acciones_exitosas   21 non-null     int64
#  4   Errores_colocador   21 non-null     int64
#  5   _error_colocador    21 non-null     int64
#  6   Puntos_negativos    21 non-null     int64
#  7   Puntos_positivos    21 non-null     int64
#  8   Acciones_positivas  21 non-null     int64
#  9   Total_acumulado     21 non-null     int64
#  10  Efic_Ranking        21 non-null     float64
#  11  id_jugador          21 non-null     object
#  12  id_equipo           21 non-null     object
#  13  temporada           21 non-null     object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 2.4+ KB

# %%
colocador = normalizar('../../data/2019-2020/colocador.csv')

# %% [markdown]
# ## Guardado en CSV.

# %%
colocador.to_csv('../../data/2019-2020/colocador.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
colocador.to_sql('colocador', engine, if_exists='append', index=False)
# Out:
# 21
