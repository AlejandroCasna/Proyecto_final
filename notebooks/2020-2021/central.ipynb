# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=69&PID=103'
parametro = 'estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Bloqueos', 'Bloqueo_exitoso',
                'Bloqueo_fallido', 'Total_bloqueos', 'Saque',
                'Errores_Saque', 'Porcentaje_error', 'Total_saques', 'Ataque_exitoso','Errores_ataque','Porc_error',
                'Total_ataques','Ataque_Ranking',2]

parametro= 'estadistica_central'

central = crear_df(datos[4],columna,parametro)
central.drop([1,2], inplace=True, axis=1)
central
# Out:
#                        Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0             Gallego Joaquín               26          100       93
# 1              Knigge Matthew               33          111       83
# 2     Dos Santos Cezar Moises               33          113       63
# 3    Levandoski Renan Roberto               26           98       82
# 4             Grossi Anderson               16           57       36
# 5  Enriquez Verdi José Manuel                8           29       13
# 6       Méndez Jiménez Víctor               25           91       43
# 7   Dos Santos Carlos Antonio               25           83       53
# 8          Guerra Uteau SImón               25           89       22
#
#   Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0              45               0            155    17            65
# 1              58               3            206    26            72
# 2              71               2            177     8            35
# 3              78               0            184    15            65
# 4              29               1             85     5            28
# 5              19               0             35     2             9
# 6              64               0            160     9            21
# 7              66               4            158     5            28
# 8              36               5            106     6            27
#
#   Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                9          285            204             22         13
# 1               18          447            244             18         15
# 2               14          267            222             27         16
# 3               10          303            185             31         20
# 4                6          156             97             13         16
# 5                5           81             47              7          5
# 6               10          270            153             26         27
# 7               10          299            148             30         19
# 8               14          284            132             22         13
#
#   Total_ataques Ataque_Ranking
# 0           341         1,6900
# 1           382         1,6847
# 2           343         1,2566
# 3           325         0,8980
# 4           178         0,8947
# 5            91         0,7586
# 6           320         0,7363
# 7           285         0,7108
# 8           270         0,6404

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2020-2021/jugadores.csv')
df.head(2)
# Out:
#    Dorsal                  Nombre  Posición  Altura  Año_de_nacimiento  \
# 0       1     García Taibo Javier  Receptor   200.0               2000
# 1       2  Paradela Cortón Miguel    Líbero   184.0               2004
#
#    Alcance_en_ataque  Alcance_en_bloqueo   id_jugador  temporada    id_equipo
# 0              316.0               330.0  1-2020-2021  2020-2021  1-2020-2021
# 1              305.0               310.0  2-2020-2021  2020-2021  1-2020-2021

# %%
central = pd.merge(central, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')
central['temporada']='2020-2021'
central
# Out:
#                        Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0             Gallego Joaquín               26          100       93
# 1              Knigge Matthew               33          111       83
# 2     Dos Santos Cezar Moises               33          113       63
# 3    Levandoski Renan Roberto               26           98       82
# 4             Grossi Anderson               16           57       36
# 5  Enriquez Verdi José Manuel                8           29       13
# 6       Méndez Jiménez Víctor               25           91       43
# 7   Dos Santos Carlos Antonio               25           83       53
# 8          Guerra Uteau SImón               25           89       22
#
#   Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0              45               0            155    17            65
# 1              58               3            206    26            72
# 2              71               2            177     8            35
# 3              78               0            184    15            65
# 4              29               1             85     5            28
# 5              19               0             35     2             9
# 6              64               0            160     9            21
# 7              66               4            158     5            28
# 8              36               5            106     6            27
#
#   Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                9          285            204             22         13
# 1               18          447            244             18         15
# 2               14          267            222             27         16
# 3               10          303            185             31         20
# 4                6          156             97             13         16
# 5                5           81             47              7          5
# 6               10          270            153             26         27
# 7               10          299            148             30         19
# 8               14          284            132             22         13
#
#   Total_ataques Ataque_Ranking     id_jugador     id_equipo  temporada
# 0           341         1,6900  106-2020-2021   8-2020-2021  2020-2021
# 1           382         1,6847   69-2020-2021   5-2020-2021  2020-2021
# 2           343         1,2566   63-2020-2021   5-2020-2021  2020-2021
# 3           325         0,8980  195-2020-2021  13-2020-2021  2020-2021
# 4           178         0,8947  120-2020-2021   9-2020-2021  2020-2021
# 5            91         0,7586  185-2020-2021  13-2020-2021  2020-2021
# 6           320         0,7363  134-2020-2021  10-2020-2021  2020-2021
# 7           285         0,7108  127-2020-2021   9-2020-2021  2020-2021
# 8           270         0,6404   23-2020-2021   2-2020-2021  2020-2021

# %%
convertir = central.columns.difference(['Nombre','id_jugador','id_equipo','temporada'])
central['Ataque_Ranking'] = central['Ataque_Ranking'].str.replace(',', '.').astype(float)
central[convertir] = central[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
central.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nombre            9 non-null      object
#  1   Partidos_jugados  9 non-null      int64
#  2   Sets_jugados      9 non-null      int64
#  3   Bloqueos          9 non-null      int64
#  4   Bloqueo_exitoso   9 non-null      int64
#  5   Bloqueo_fallido   9 non-null      int64
#  6   Total_bloqueos    9 non-null      int64
#  7   Saque             9 non-null      int64
#  8   Errores_Saque     9 non-null      int64
#  9   Porcentaje_error  9 non-null      int64
#  10  Total_saques      9 non-null      int64
#  11  Ataque_exitoso    9 non-null      int64
#  12  Errores_ataque    9 non-null      int64
#  13  Porc_error        9 non-null      int64
#  14  Total_ataques     9 non-null      int64
#  15  Ataque_Ranking    9 non-null      float64
#  16  id_jugador        9 non-null      object
#  17  id_equipo         9 non-null      object
#  18  temporada         9 non-null      object
# dtypes: float64(1), int64(14), object(4)
# memory usage: 1.5+ KB

# %%
central=normalizar('../../data/2020-2021/central.csv')

# %% [markdown]
# ## Guardado en CSV.

# %%
central.to_csv('../../data/2020-2021/central.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
central.to_sql('central', engine, if_exists='append', index=False)
# Out:
# 9
