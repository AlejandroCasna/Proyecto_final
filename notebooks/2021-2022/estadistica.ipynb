# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_datos import *
from src.help_scraping import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=82&PID=122'
parametro = 'estadistica_equipo'
dato=scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Equipo', 'Jugados', 'Sets_Jugados', 'Total_Puntos', 'Break_Puntos', 'Puntos_Ganados',
            'Puntos_Perdidos', 'Total_Saque', 'Puntos_Saque', 'Error_Saque', 'Puntos_por_set_Saque',
            'Efic_Saque', 'Total_Recepcion', 'Error_Recepcion', 'Negativo_Recepcion', 'Positivo_Recepcion',
            'Excelente_Recepcion', 'Efic_Recepcion', 'Total_Ataque', 'Error_Ataque', 'Ataque_Bloqueado',
            'Positivo_Ataque', 'Excelente_Ataque', 'Efic_Ataque', 'Toque_Red_Bloqueo', 'Puntos_de_Bloqueo',
            'Puntos_Set_Bloqueo']

parametro = 'estadistica'
estadistica=crear_df(dato,columna,parametro)

# %%
mapear_nombres(estadistica)
# Out:
#                   Equipo  Jugados  Sets_Jugados  Total_Puntos  Break_Puntos  \
# 0             CV Melilla       29           111          1838           721
# 1        Unicaja Almería       28           112          1795           762
# 2                Guaguas       28           104          1777           696
# 3              CV Teruel       25            99          1610           557
# 4            Voley Palma       26            99          1592           562
# 5        Rio Duero Soria       23            90          1440           520
# 6                Manacor       24            89          1434           520
# 7          Rotogal Boiro       23            95          1407           486
# 8   Conqueridor Valencia       22            81          1161           435
# 9           Arenal Emevé       22            84          1152           343
# 10                Intasa       22            79          1108           338
# 11           Ibiza Voley       22            75          1053           332
#
#     Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  Error_Saque  \
# 0             1117              901         2543           144          376
# 1             1033             1017         2465           164          329
# 2             1081              898         2425           166          369
# 3             1053              754         2213           117          361
# 4             1030              711         2215           115          307
# 5              920              655         2007           121          329
# 6              914              527         1981           147          406
# 7              921              560         2009           111          335
# 8              726              333         1697           122          310
# 9              809              336         1712            59          260
# 10             770              383         1588            73          259
# 11             721              296         1542            81          269
#
#     ...  Efic_Recepcion  Total_Ataque  Error_Ataque  Ataque_Bloqueado  \
# 0   ...            24.0          2780           213               220
# 1   ...            21.0          2634           146               185
# 2   ...            29.0          2629           205               213
# 3   ...            28.0          2546           196               189
# 4   ...            31.0          2769           238               228
# 5   ...            24.0          2194           163               188
# 6   ...            32.0          2174           192               187
# 7   ...            30.0          2231           204               184
# 8   ...            24.0          1874           189               183
# 9   ...            35.0          2197           234               222
# 10  ...            30.0          2002           172               181
# 11  ...            29.0          1983           208               165
#
#     Positivo_Ataque  Excelente_Ataque  Efic_Ataque  Toque_Red_Bloqueo  \
# 0              1425              51.0         36.0                185
# 1              1318              50.0         37.0                358
# 2              1374              52.0         36.0                293
# 3              1270              50.0         35.0                119
# 4              1296              47.0         30.0                131
# 5              1110              51.0         35.0                226
# 6              1096              50.0         33.0                 75
# 7              1121              50.0         33.0                106
# 8               902              48.0         28.0                155
# 9               972              44.0         23.0                 79
# 10              892              45.0         27.0                119
# 11              826              42.0         23.0                 57
#
#     Puntos_de_Bloqueo  Puntos_Set_Bloqueo
# 0                 269                 2.4
# 1                 313                 2.8
# 2                 237                 2.3
# 3                 223                 2.3
# 4                 181                 1.8
# 5                 209                 2.3
# 6                 191                 2.1
# 7                 175                 1.8
# 8                 137                 1.7
# 9                 121                 1.4
# 10                143                 1.8
# 11                146                 1.9
#
# [12 rows x 27 columns]

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2021-2022/equipo.csv')
df
# Out:
#                   Equipo     id_equipo
# 0           Arenal Emevé   1-2021-2022
# 1              CV Teruel   2-2021-2022
# 2                Manacor   3-2021-2022
# 3                Guaguas   4-2021-2022
# 4            Voley Palma   5-2021-2022
# 5                 Intasa   6-2021-2022
# 6   Conqueridor Valencia   7-2021-2022
# 7             CV Melilla   8-2021-2022
# 8        Rio Duero Soria   9-2021-2022
# 9          Rotogal Boiro  10-2021-2022
# 10           Ibiza Voley  11-2021-2022
# 11       Unicaja Almería  12-2021-2022

# %%
estadistica = pd.merge(estadistica, df[['Equipo', 'id_equipo']], left_on='Equipo', right_on='Equipo', how='left')
estadistica.head()
# Out:
#             Equipo  Jugados  Sets_Jugados  Total_Puntos  Break_Puntos  \
# 0       CV Melilla       29           111          1838           721
# 1  Unicaja Almería       28           112          1795           762
# 2          Guaguas       28           104          1777           696
# 3        CV Teruel       25            99          1610           557
# 4      Voley Palma       26            99          1592           562
#
#    Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  Error_Saque  \
# 0            1117              901         2543           144          376
# 1            1033             1017         2465           164          329
# 2            1081              898         2425           166          369
# 3            1053              754         2213           117          361
# 4            1030              711         2215           115          307
#
#    ...  Total_Ataque  Error_Ataque  Ataque_Bloqueado  Positivo_Ataque  \
# 0  ...          2780           213               220             1425
# 1  ...          2634           146               185             1318
# 2  ...          2629           205               213             1374
# 3  ...          2546           196               189             1270
# 4  ...          2769           238               228             1296
#
#    Excelente_Ataque  Efic_Ataque  Toque_Red_Bloqueo  Puntos_de_Bloqueo  \
# 0              51.0         36.0                185                269
# 1              50.0         37.0                358                313
# 2              52.0         36.0                293                237
# 3              50.0         35.0                119                223
# 4              47.0         30.0                131                181
#
#    Puntos_Set_Bloqueo     id_equipo
# 0                 2.4   8-2021-2022
# 1                 2.8  12-2021-2022
# 2                 2.3   4-2021-2022
# 3                 2.3   2-2021-2022
# 4                 1.8   5-2021-2022
#
# [5 rows x 28 columns]

# %%
estadistica['temporada']='2021-2022'

# %%
estadistica=normalizar('../../data/2021-2022/estadistica.csv')

# %% [markdown]
# ## Guardado en CSV.

# %%
estadistica.to_csv('../../data/2021-2022/estadistica.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
estadistica.to_sql('estadistica', engine, if_exists='append', index=False)
# Out:
# 12
