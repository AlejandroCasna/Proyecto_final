# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=82&PID=122'
parametro='estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Recepciones', 'Recepciones_exitosas',
                'Recepciones_fallidas', 'Recepciones_otro_jugador', 'Puntos_perdidos_recep',
                'Puntos_ganados_recep', 'Total_puntos_recep', 'Recep_Ranking', 12]

parametro= 'estadistica_libero'

libero = crear_df(datos[1],columna,parametro)

# %%
libero.drop([1,12], inplace=True, axis=1)

# %%
libero=normalizar_df(libero)

# %%
libero
# Out:
#                                Nombre Partidos_jugados Sets_jugados  \
# 0        Bernabeu Judez Joaquin Jesus                1            1
# 1                         Ruiz Daniel               26           99
# 2                     Delgado Gustavo                8           17
# 3                 Osado Carrasco Jose               19           58
# 4              Piris Guiscafre Antoni               24           86
# 5      San Martin Rodriguez Alejandro               22           79
# 6              Mengod Bautista Javier               20           67
# 7                Dovale Fidalgo Mario               22           84
# 8                Pinon Hermida Marcos               21           74
# 9           Fernandez Rojas Alejandro               25           91
# 10               Ferrera Garcia Mario               28          105
# 11                Gamiz Padilla Aaron               24           96
# 12                Gomez Moreno Manuel                1            3
# 13                Alves Castro Adrian               23           92
# 14          Giustiniano Mariano Ariel                1            4
# 15  Fernandez Martinez Francisco Jose               28          106
# 16            Salvador Esteban Manuel                2            8
# 17                Sanchez Cano Victor                6           18
# 18                  Vildosola Mariano                1            3
# 19             Izquierdo Marin Javier               10           23
#
#    Recepciones Recepciones_exitosas Recepciones_fallidas  \
# 0            3                    0                    0
# 1          245                   17                   12
# 2           37                    1                    0
# 3          189                   27                   18
# 4          225                   41                    9
# 5          153                   22                   32
# 6          202                   38                   32
# 7          197                   29                   17
# 8          181                   27                   40
# 9          193                   26                   26
# 10         230                   40                   19
# 11         172                   30                   22
# 12           9                    1                    0
# 13         191                   42                   11
# 14           8                    3                    0
# 15         195                   42                   50
# 16          10                    4                    7
# 17          34                   12                   21
# 18           6                    2                    0
# 19          34                   17                    5
#
#    Recepciones_otro_jugador Puntos_perdidos_recep Puntos_ganados_recep  \
# 0                         0                     1                    2
# 1                        14                    65                  157
# 2                         8                    10                   21
# 3                        26                    46                   88
# 4                        18                   105                  128
# 5                        10                    62                  115
# 6                        17                   103                  102
# 7                        28                   104                  112
# 8                        37                    28                   97
# 9                        27                   107                  128
# 10                       33                    91                  196
# 11                       22                    65                  162
# 12                        3                     6                    1
# 13                       36                   123                  116
# 14                        0                    10                    3
# 15                       32                   111                  184
# 16                        0                     5                   23
# 17                        8                    21                   27
# 18                        2                     4                    5
# 19                        3                    49                   30
#
#    Total_puntos_recep Recep_Ranking
# 0                   6        0,5000
# 1                 510        0,4196
# 2                  77        0,3636
# 3                 394        0,3452
# 4                 526        0,3156
# 5                 394        0,3071
# 6                 494        0,2976
# 7                 487        0,2875
# 8                 410        0,2854
# 9                 507        0,2761
# 10                609        0,2578
# 11                473        0,2537
# 12                 20        0,2500
# 13                519        0,2177
# 14                 24        0,2083
# 15                614        0,1971
# 16                 49        0,1224
# 17                123        0,1138
# 18                 19        0,1053
# 19                138        0,1014

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2021-2022/jugadores.csv')
df.head()
# Out:
#    Dorsal                      Nombre        Posicion  Altura  \
# 0       1             Alzueta Joaquin  Middle-blocker   196.0
# 1       2      Paradela Corton Miguel          Libero   184.0
# 2       3       Bouza Ferreiro Victor        Receptor   187.0
# 3       7  Loeches Buitrago Guillermo     Colocador/a   181.0
# 4       8       Marino Gonzalez Anier  Middle-blocker   184.0
#
#    Ano_de_nacimiento  Alcance_en_ataque  Alcance_en_bloqueo   id_jugador  \
# 0               2000              337.0               323.0  1-2021-2022
# 1               2004              310.0               305.0  2-2021-2022
# 2               1990              330.0               320.0  3-2021-2022
# 3               1996              306.0               297.0  4-2021-2022
# 4               2005              310.0               300.0  5-2021-2022
#
#    temporada    id_equipo
# 0  2021-2022  1-2021-2022
# 1  2021-2022  1-2021-2022
# 2  2021-2022  1-2021-2022
# 3  2021-2022  1-2021-2022
# 4  2021-2022  1-2021-2022

# %%
liberos = pd.merge(libero, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')
liberos['temporada'] = '2021-2022'
liberos.head(2)
# Out:
#                          Nombre Partidos_jugados Sets_jugados Recepciones  \
# 0  Bernabeu Judez Joaquin Jesus                1            1           3
# 1                   Ruiz Daniel               26           99         245
#
#   Recepciones_exitosas Recepciones_fallidas Recepciones_otro_jugador  \
# 0                    0                    0                        0
# 1                   17                   12                       14
#
#   Puntos_perdidos_recep Puntos_ganados_recep Total_puntos_recep Recep_Ranking  \
# 0                     1                    2                  6        0,5000
# 1                    65                  157                510        0,4196
#
#      id_jugador    id_equipo  temporada
# 0  96-2021-2022  7-2021-2022  2021-2022
# 1  61-2021-2022  5-2021-2022  2021-2022

# %%
convertir = liberos.columns.difference(['Nombre'])
liberos['Recep_Ranking'] = liberos['Recep_Ranking'].str.replace(',', '.').astype(float)
liberos[convertir] = liberos[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
liberos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre                    20 non-null     object
#  1   Partidos_jugados          20 non-null     int64
#  2   Sets_jugados              20 non-null     int64
#  3   Recepciones               20 non-null     int64
#  4   Recepciones_exitosas      20 non-null     int64
#  5   Recepciones_fallidas      20 non-null     int64
#  6   Recepciones_otro_jugador  20 non-null     int64
#  7   Puntos_perdidos_recep     20 non-null     int64
#  8   Puntos_ganados_recep      20 non-null     int64
#  9   Total_puntos_recep        20 non-null     int64
#  10  Recep_Ranking             20 non-null     float64
#  11  id_jugador                20 non-null     object
#  12  id_equipo                 20 non-null     object
#  13  temporada                 20 non-null     object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 2.3+ KB

# %% [markdown]
# ## Guardado en CSV.

# %%
liberos.to_csv('../../data/2021-2022/liberos.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
liberos.to_sql('libero', engine, if_exists='append', index=False)
# Out:
# 20
