# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_datos import *
from src.help_scraping import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=111&PID=137'
parametro = 'estadistica_equipo'
dato=scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Equipo', 'Jugados', 'Sets_Jugados', 'Total_Puntos', 'Break_Puntos', 'Puntos_Ganados',
            'Puntos_Perdidos', 'Total_Saque', 'Puntos_Saque', 'Error_Saque', 'Puntos_por_set_Saque',
            'Efic_Saque', 'Total_Recepcion', 'Error_Recepcion', 'Negativo_Recepcion', 'Positivo_Recepcion',
            'Excelente_Recepcion', 'Efic_Recepcion', 'Total_Ataque', 'Error_Ataque', 'Ataque_Bloqueado',
            'Positivo_Ataque', 'Excelente_Ataque', 'Efic_Ataque', 'Toque_Red_Bloqueo', 'Puntos_de_Bloqueo',
            'Puntos_Set_Bloqueo']

parametro = 'estadistica'
estadistica=crear_df(dato,columna,parametro)

# %%
mapear_nombres(estadistica)
# Out:
#                        Equipo  Jugados  Sets_Jugados  Total_Puntos  \
# 0             Rio Duero Soria       30           109          1752
# 1                     Guaguas       29            97          1735
# 2                   CV Teruel       28           102          1635
# 3                  CV Melilla       27            96          1570
# 4        Conqueridor Valencia       25            94          1539
# 5             Unicaja Almería       25            91          1438
# 6                Arenal Emevé       24            86          1310
# 7              Barça Voleibol       24            84          1294
# 8                 Voley Palma       22            83          1239
# 9                     Manacor       22            77          1201
# 10  Voley Textil Santanderina       22            75          1010
# 11              Rotogal Boiro       22            72           910
#
#     Break_Puntos  Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  \
# ...

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2022-2023/Equipo.csv')
df
# Out:
#                        Equipo     id_equipo
# 0                Arenal Emeve   1-2022-2023
# 1              Barca Voleibol   2-2022-2023
# 2                 Voley Palma   3-2022-2023
# 3                     Manacor   4-2022-2023
# 4                     Guaguas   5-2022-2023
# 5        Conqueridor Valencia   6-2022-2023
# 6                  CV Melilla   7-2022-2023
# 7                   CV Teruel   8-2022-2023
# 8             Rio Duero Soria   9-2022-2023
# 9               Rotogal Boiro  10-2022-2023
# 10            Unicaja Almeria  11-2022-2023
# 11  Voley Textil Santanderina  12-2022-2023

# %%
estadistica= pd.read_csv('../../data/2022-2023/estadistica.csv')
estadistica
# Out:
#                        Equipo  Jugados  Sets_Jugados  Total_Puntos  \
# 0             Rio Duero Soria       30           109          1752
# 1                     Guaguas       29            97          1735
# 2                   CV Teruel       28           102          1635
# 3                  CV Melilla       27            96          1570
# 4        Conqueridor Valencia       25            94          1539
# 5             Unicaja Almeria       25            91          1438
# 6                Arenal Emeve       24            86          1310
# 7              Barca Voleibol       24            84          1294
# 8                 Voley Palma       22            83          1239
# 9                     Manacor       22            77          1201
# 10  Voley Textil Santanderina       22            75          1010
# 11              Rotogal Boiro       22            72           910
#
#     Break_Puntos  Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  \
# ...

# %%
result = pd.merge(estadistica, df[['Equipo', 'id_equipo']], left_on='Equipo', right_on='Equipo', how='left')
result['temporada']='2022-2023'
result.head(2)
# Out:
#             Equipo  Jugados  Sets_Jugados  Total_Puntos  Break_Puntos  \
# 0  Rio Duero Soria       30           109          1752           671
# 1          Guaguas       29            97          1735           781
#
#    Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  Error_Saque  \
# 0            1081              669         2526           156          489
# 1             954              965         2366           177          355
#
#    ...  Error_Ataque  Ataque_Bloqueado  Positivo_Ataque  Excelente_Ataque  \
# 0  ...           232               239             1353              47.0
# 1  ...           173               164             1312              54.0
#
#    Efic_Ataque  Toque_Red_Bloqueo  Puntos_de_Bloqueo  Puntos_Set_Bloqueo  \
# 0         31.0                377                243                 2.2
# 1         40.0                297                248                 2.6
#
#      id_equipo  temporada
# 0  9-2022-2023  2022-2023
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Equipo                12 non-null     object
#  1   Jugados               12 non-null     int64
#  2   Sets_Jugados          12 non-null     int64
#  3   Total_Puntos          12 non-null     int64
#  4   Break_Puntos          12 non-null     int64
#  5   Puntos_Ganados        12 non-null     int64
#  6   Puntos_Perdidos       12 non-null     int64
#  7   Total_Saque           12 non-null     int64
#  8   Puntos_Saque          12 non-null     int64
#  9   Error_Saque           12 non-null     int64
#  10  Puntos_por_set_Saque  12 non-null     float64
#  11  Efic_Saque            12 non-null     float64
#  12  Total_Recepcion       12 non-null     int64
#  13  Error_Recepcion       12 non-null     int64
#  14  Negativo_Recepcion    12 non-null     int64
# ...

# %%
result=normalizar('../../data/2022-2023/estadistica.csv')
result
# Out:
#                        Equipo  Jugados  Sets_Jugados  Total_Puntos  \
# 0             Rio Duero Soria       30           109          1752
# 1                     Guaguas       29            97          1735
# 2                   CV Teruel       28           102          1635
# 3                  CV Melilla       27            96          1570
# 4        Conqueridor Valencia       25            94          1539
# 5             Unicaja Almeria       25            91          1438
# 6                Arenal Emeve       24            86          1310
# 7              Barca Voleibol       24            84          1294
# 8                 Voley Palma       22            83          1239
# 9                     Manacor       22            77          1201
# 10  Voley Textil Santanderina       22            75          1010
# 11              Rotogal Boiro       22            72           910
#
#     Break_Puntos  Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  \
# ...

# %% [markdown]
# ## Guardado en CSV.

# %%
result.to_csv('../../data/2022-2023/estadistica.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
estadistica.to_sql('estadisticas_temporada_anterior', engine, if_exists='append', index=False)
# Out:
# 12
