# %%
import sys
sys.path.append("C:\ironhack\Proyecto_final") 
from src.funciones import *

# %%
url = 'https://rfevb-web.dataproject.com/CompetitionHome.aspx?ID=111'
driver = webdriver.Chrome(options = opciones)
driver.get(url)

# %%
driver.find_element(By.XPATH,'//*[@id="ctl00_RM_CompetitionArea_Main"]/ul/li[5]/a').click()

# %%
superLiga_Masculino=[]
for i in range(12):
                
    e = driver.find_elements(By.CLASS_NAME, 'rlvI')[i]
                
    print(e.text)
                
    e.click()
                
    print('Estoy dentro.')
                
    time.sleep(1)
            
    superLiga_Masculino.append(driver.find_elements(By.CLASS_NAME , 't-row')[3].text.split('\n'))
                
    print('Extraigo')
                
    time.sleep(1)
                
    driver.get('https://rfevb-web.dataproject.com/CompetitionTeamSearch.aspx?ID=111')
# Out:
# Arenal Emevé
# Estoy dentro.
# Extraigo
# Barça Voleibol
# Estoy dentro.
# Extraigo
# Club Vóley Palma
# Estoy dentro.
# Extraigo
# Conectabalear CV Manacor
# Estoy dentro.
# Extraigo
# CV Guaguas
# Estoy dentro.
# Extraigo
# Léleman Conqueridor Valencia
# Estoy dentro.
# Extraigo
# Melilla Sport Capital
# Estoy dentro.
# Extraigo
# Pamesa Teruel Voleibol
# Estoy dentro.
# Extraigo
# Rio Duero Soria
# Estoy dentro.
# Extraigo
# Rotogal Boiro
# Estoy dentro.
# Extraigo
# Unicaja Costa de Almeria
# Estoy dentro.
# Extraigo
# Voley Textil Santanderina
# Estoy dentro.
# Extraigo

# %%
superLiga_Masculino[0][0:8]
# Out:
# ['#',
#  'Nombre',
#  'Posición',
#  'Altura',
#  'Año de nacimiento',
#  'Alcance en ataque',
#  'Alcance en bloqueo',
#  '1']

# %%
len(superLiga_Masculino)
# Out:
# 12

# %%
columnas = ['Dorsal', 'Nombre', '1', 'Posición', 'Altura', 'Año de nacimiento', 'Alcance en ataque', 'Alcance en bloqueo']
filas_organizadas = []

for equipo in superLiga_Masculino:
    datos_filas = equipo[7:]
    num_filas = len(datos_filas) // len(columnas)
    filas_equipo = [datos_filas[i:i + len(columnas)] for i in range(0, len(datos_filas), len(columnas))]
    filas_organizadas.extend(filas_equipo)

jugadores = pd.DataFrame(filas_organizadas, columns=columnas)
jugadores.head()
# Out:
#   Dorsal                      Nombre                    1        Posición  \
# 0      1     Ferreira García Gabriel  Hasta el 09/09/2023     Colocador/a
# 1      2           Alves Ramos Vitor  Hasta el 09/09/2023        Receptor
# 2      3       Bouza Ferreiro Víctor  Hasta el 09/09/2023        Receptor
# 3      4      Romaní Leandro Gustavo  Hasta el 09/09/2023  Middle-blocker
# 4      7  Gallardo Hernández Rodrigo  Hasta el 09/09/2023          Líbero
#
#   Altura Año de nacimiento Alcance en ataque Alcance en bloqueo
# 0    188              1997               310                300
# 1    194              2002               330                322
# 2    187              1990               330                320
# 3    205              1999               337                323
# 4    183              1999               295                268

# %%
jugadores = jugadores.drop('1', axis=1)

jugadores
# Out:
#     Dorsal                        Nombre        Posición Altura  \
# 0        1       Ferreira García Gabriel     Colocador/a    188
# 1        2             Alves Ramos Vitor        Receptor    194
# 2        3         Bouza Ferreiro Víctor        Receptor    187
# 3        4        Romaní Leandro Gustavo  Middle-blocker    205
# 4        7    Gallardo Hernández Rodrigo          Líbero    183
# ..     ...                           ...             ...    ...
# 172     11          Campos Canals Miquel  Middle-blocker    187
# 173     12      Corona Mediavilla Fabián        Receptor    185
# 174     13  Calzón Algaba Francisco José  Middle-blocker    198
# 175     14  Frías Collado Juan Francisco  Middle-blocker    198
# 176     17     Rodríguez Bonilla Roberto        Receptor    190
#
#     Año de nacimiento Alcance en ataque Alcance en bloqueo
# 0                1997               310                300
# 1                2002               330                322
# ...

# %%
jugadores['id_jugador'] = range(200, 200 + len(jugadores))
jugadores['temporada'] = '2022-2023'
jugadores.columns = jugadores.columns.str.replace(' ', '_')
jugadores
# Out:
#     Dorsal                        Nombre        Posición Altura  \
# 0        1       Ferreira García Gabriel     Colocador/a    188
# 1        2             Alves Ramos Vitor        Receptor    194
# 2        3         Bouza Ferreiro Víctor        Receptor    187
# 3        4        Romaní Leandro Gustavo  Middle-blocker    205
# 4        7    Gallardo Hernández Rodrigo          Líbero    183
# ..     ...                           ...             ...    ...
# 172     11          Campos Canals Miquel  Middle-blocker    187
# 173     12      Corona Mediavilla Fabián        Receptor    185
# 174     13  Calzón Algaba Francisco José  Middle-blocker    198
# 175     14  Frías Collado Juan Francisco  Middle-blocker    198
# 176     17     Rodríguez Bonilla Roberto        Receptor    190
#
#     Año_de_nacimiento Alcance_en_ataque Alcance_en_bloqueo  id_jugador  \
# 0                1997               310                300         200
# ...

# %%
jugadores.to_csv('../../data/2022-2023/jugadores.csv', index=False)

# %%
jugadores.loc[0:13, 'id_equipo'] = 1
jugadores.loc[14:28, 'id_equipo'] = 2
jugadores.loc[29:48, 'id_equipo'] = 3
jugadores.loc[49:60, 'id_equipo'] = 4
jugadores.loc[61:75, 'id_equipo'] = 5
jugadores.loc[76:90, 'id_equipo'] = 6
jugadores.loc[91:103, 'id_equipo'] = 7
jugadores.loc[104:115, 'id_equipo'] = 8
jugadores.loc[108:129, 'id_equipo'] = 9
jugadores.loc[130:146, 'id_equipo'] = 10
jugadores.loc[147:162, 'id_equipo'] = 11
jugadores.loc[163:, 'id_equipo'] = 12
jugadores['id_equipo'] = jugadores['id_equipo'].astype(int)

# %%
jugadores.replace('-', np.nan, inplace=True)

jugadores[['Alcance_en_ataque', 'Alcance_en_bloqueo', 'Altura']] = jugadores[['Alcance_en_ataque', 'Alcance_en_bloqueo', 'Altura']].astype(float)

# %%
jugadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Dorsal              175 non-null    object
#  1   Nombre              177 non-null    object
#  2   Posición            176 non-null    object
#  3   Altura              169 non-null    float64
#  4   Año_de_nacimiento   172 non-null    object
#  5   Alcance_en_ataque   95 non-null     float64
#  6   Alcance_en_bloqueo  95 non-null     float64
#  7   id_jugador          177 non-null    int64
#  8   temporada           177 non-null    object
#  9   id_equipo           177 non-null    int32
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 13.3+ KB

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyball_database')

# %%
dtype = {'id_jugador': Integer}
jugadores.to_sql('jugadores', engine, if_exists='append', index=False, dtype=dtype)
# Out:
# 177
