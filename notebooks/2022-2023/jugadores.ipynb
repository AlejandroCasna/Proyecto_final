# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/CompetitionTeamSearch.aspx?ID=111'
parametro = 'jugadores'
datos= scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Arenal Emevé
# Estoy dentro.
# Extraigo
# Barça Voleibol
# Estoy dentro.
# Extraigo
# Club Vóley Palma
# Estoy dentro.
# Extraigo
# Conectabalear CV Manacor
# Estoy dentro.
# Extraigo
# CV Guaguas
# Estoy dentro.
# Extraigo
# Léleman Conqueridor Valencia
# Estoy dentro.
# Extraigo
# Melilla Sport Capital
# Estoy dentro.
# Extraigo
# Pamesa Teruel Voleibol
# Estoy dentro.
# Extraigo
# Rio Duero Soria
# Estoy dentro.
# Extraigo
# Rotogal Boiro
# Estoy dentro.
# Extraigo
# Unicaja Costa de Almeria
# Estoy dentro.
# Extraigo
# Voley Textil Santanderina
# Estoy dentro.
# Extraigo
# Scraping exitoso

# %%
columna = ['Dorsal', 'Nombre', '1', 'Posición', 'Altura', 'Año de nacimiento', 'Alcance en ataque', 'Alcance en bloqueo']
parametro = 'jugadores'
jugadores=crear_df(datos,columna,parametro)
jugadores
# Out:
#     Dorsal                        Nombre                    1        Posición  \
# 0        1       Ferreira García Gabriel  Hasta el 09/09/2023     Colocador/a
# 1        2             Alves Ramos Vitor  Hasta el 09/09/2023        Receptor
# 2        3         Bouza Ferreiro Víctor  Hasta el 09/09/2023        Receptor
# 3        4        Romaní Leandro Gustavo  Hasta el 09/09/2023  Middle-blocker
# 4        7    Gallardo Hernández Rodrigo  Hasta el 09/09/2023          Líbero
# ..     ...                           ...                  ...             ...
# 172     11          Campos Canals Miquel  Hasta el 09/09/2023  Middle-blocker
# 173     12      Corona Mediavilla Fabián  Hasta el 09/09/2023        Receptor
# 174     13  Calzón Algaba Francisco José  Hasta el 09/09/2023  Middle-blocker
# 175     14  Frías Collado Juan Francisco  Hasta el 09/09/2023  Middle-blocker
# 176     17     Rodríguez Bonilla Roberto  Hasta el 09/09/2023        Receptor
#
#     Altura Año de nacimiento Alcance en ataque Alcance en bloqueo
# 0      188              1997               310                300
# 1      194              2002               330                322
# 2      187              1990               330                320
# 3      205              1999               337                323
# 4      183              1999               295                268
# ..     ...               ...               ...                ...
# 172    187              2001               325                315
# 173    185              2003               310                305
# 174    198              1992               330                320
# 175    198              2000               325                315
# 176    190              2000               335                320
#
# [177 rows x 8 columns]

# %%
jugadores['id_jugador'] = [str(i) + '-2022-2023' for i in range(1, len(jugadores) + 1)]
jugadores['temporada'] = '2022-2023'
jugadores.columns = jugadores.columns.str.replace(' ', '_')
jugadores.loc[0:13, 'id_equipo'] = '1-2022-2023'
jugadores.loc[14:28, 'id_equipo'] = '2-2022-2023'
jugadores.loc[29:48, 'id_equipo'] = '3-2022-2023'
jugadores.loc[49:60, 'id_equipo'] = '4-2022-2023'
jugadores.loc[61:75, 'id_equipo'] = '5-2022-2023'
jugadores.loc[76:90, 'id_equipo'] = '6-2022-2023'
jugadores.loc[91:103, 'id_equipo'] = '7-2022-2023'
jugadores.loc[104:115, 'id_equipo'] = '8-2022-2023'
jugadores.loc[116:129, 'id_equipo'] = '9-2022-2023'
jugadores.loc[130:146, 'id_equipo'] = '10-2022-2023'
jugadores.loc[147:162, 'id_equipo'] = '11-2022-2023'
jugadores.loc[163:, 'id_equipo'] = '12-2022-2023'
jugadores.drop('1', axis=1, inplace=True)
jugadores.replace('-', '0', inplace=True)
jugadores[['Alcance_en_ataque', 'Alcance_en_bloqueo', 'Altura']] = jugadores[['Alcance_en_ataque', 'Alcance_en_bloqueo', 'Altura']].astype(float)
jugadores['Año_de_nacimiento'] = pd.to_numeric(jugadores['Año_de_nacimiento'], errors='coerce').fillna(0).astype(int)
jugadores.rename(columns={'#': 'Dorsal'}, inplace=True)
jugadores.head()
# Out:
#   Dorsal                      Nombre                    1        Posición  \
# 0      1     Ferreira García Gabriel  Hasta el 09/09/2023     Colocador/a
# 1      2           Alves Ramos Vitor  Hasta el 09/09/2023        Receptor
# 2      3       Bouza Ferreiro Víctor  Hasta el 09/09/2023        Receptor
# 3      4      Romaní Leandro Gustavo  Hasta el 09/09/2023  Middle-blocker
# 4      7  Gallardo Hernández Rodrigo  Hasta el 09/09/2023          Líbero
#
#    Altura  Año_de_nacimiento  Alcance_en_ataque  Alcance_en_bloqueo  \
# 0   188.0               1997              310.0               300.0
# 1   194.0               2002              330.0               322.0
# 2   187.0               1990              330.0               320.0
# 3   205.0               1999              337.0               323.0
# 4   183.0               1999              295.0               268.0
#
#     id_jugador  temporada    id_equipo
# 0  1-2022-2023  2022-2023  1-2022-2023
# 1  2-2022-2023  2022-2023  1-2022-2023
# 2  3-2022-2023  2022-2023  1-2022-2023
# 3  4-2022-2023  2022-2023  1-2022-2023
# 4  5-2022-2023  2022-2023  1-2022-2023

# %%
jugadores=normalizar('../../data/2022-2023/jugadores.csv')

# %% [markdown]
# ## Guardado en CSV.

# %%
jugadores.to_csv('../../data/2022-2023/jugadores.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
jugadores.to_sql('jugadores', engine, if_exists='append', index=False)
# Out:
# 177
