# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
import pandas as pd
from src.funciones import *

# %%
url = 'https://rfevb-web.dataproject.com/CompetitionHome.aspx?ID=111'
driver = webdriver.Chrome(options = opciones)
driver.get(url)

# %%
driver.find_element(By.XPATH,'//*[@id="ctl00_RM_CompetitionArea_Main"]/ul/li[4]/a/span').click()

# %%
info= driver.find_element(By.XPATH,'//*[@id="RG_PlayerRanking_Libero"]').text.split('\n')

# %%
info = [info[i:i+13] for i in range(3, len(info), 13)]

libero = pd.DataFrame(info)

column_names = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Recepciones', 'Recepciones_exitosas',
                'Recepciones_fallidas', 'Recepciones_otro_jugador', 'Puntos_perdidos_recep',
                'Puntos_ganados_recep', 'Total_puntos_recep', 'Recep_Ranking', 12]

libero.columns = column_names
libero.drop([1,12], inplace=True, axis=1)
libero
# Out:
#                                Nombre Partidos_jugados Sets_jugados  \
# 0                 Larrañaga Ledo Unai               26           90
# 1                 Conde Barrios Lucas                1            3
# 2                  Masia Porres Arnau               24           84
# 3                 Osado Carrasco José               22           83
# 4                         Ruiz Daniel               23           70
# 5            Ruda Martínez Florentino                1            4
# 6           Fernández Rojas Alejandro               16           41
# 7      San Martín Rodríguez Alejandro               30          109
# 8                Gámiz Padilla Aharón               28          102
# 9                 Sánchez Cano Víctor               21           70
# 10  Fernández Martínez Francisco José               20           74
# 11             Piris Guiscafré Antoni               21           74
# 12             Mengod Bautista Javier               24           87
# 13           Barrasa Portomeñe Samuel               15           46
# 14                Alves Castro Adrián               22           71
# 15          Giustiniano Mariano Ariel                1            3
# 16               Redonda Camaño David                1            3
# 17       Giménez Hernández José María                5           17
# 18         Gallardo Hernández Rodrigo               19           53
# 19            Iborra Ballester Héctor                5           11
#
#    Recepciones Recepciones_exitosas Recepciones_fallidas  \
# 0          232                   32                   18
# 1           11                    0                    0
# 2          196                   31                   15
# 3          236                   27                   20
# 4          130                   12                   13
# 5           16                    5                    0
# 6           55                   12                    0
# 7          169                   38                   31
# 8          152                   22                   47
# 9          141                   28                   10
# 10         141                   24                   51
# 11         173                   44                   12
# 12         216                   40                   89
# 13          92                   18                   15
# 14         177                   48                   11
# 15           5                    2                    0
# 16           5                    0                    0
# 17          27                    6                   13
# 18          73                   24                    9
# 19          16                    6                    5
#
#    Recepciones_otro_jugador Puntos_perdidos_recep Puntos_ganados_recep  \
# 0                        14                    67                   94
# 1                         1                     7                    6
# 2                        21                    78                  118
# 3                        34                    96                  181
# 4                        21                    60                  102
# 5                         1                     8                    5
# 6                         8                    20                   28
# 7                         9                    71                  155
# 8                        16                    70                  136
# 9                        22                    56                  107
# 10                       17                    88                  112
# 11                       27                    90                  108
# 12                       27                   158                  164
# 13                       15                    60                   77
# 14                       30                   111                   95
# 15                        0                     7                    1
# 16                        2                     3                    6
# 17                        4                    17                   28
# 18                       20                    68                   86
# 19                        6                    23                   18
#
#    Total_puntos_recep Recep_Ranking
# 0                 457        0,4070
# 1                  25        0,4000
# 2                 459        0,3137
# 3                 594        0,2946
# 4                 338        0,2870
# 5                  35        0,2857
# 6                 123        0,2846
# 7                 473        0,2579
# 8                 443        0,2573
# 9                 364        0,2500
# 10                433        0,2309
# 11                454        0,2247
# 12                694        0,2147
# 13                277        0,2130
# 14                472        0,2097
# 15                 15        0,2000
# 16                 16        0,1875
# 17                 95        0,1789
# 18                280        0,1036
# 19                 74        0,0541

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../data/2022-2023/jugadores.csv')
df
# Out:
#     Dorsal                        Nombre        Posición Altura  \
# 0        1       Ferreira García Gabriel     Colocador/a    188
# 1        2             Alves Ramos Vitor        Receptor    194
# 2        3         Bouza Ferreiro Víctor        Receptor    187
# 3        4        Romaní Leandro Gustavo  Middle-blocker    205
# 4        7    Gallardo Hernández Rodrigo          Líbero    183
# ..     ...                           ...             ...    ...
# 172     11          Campos Canals Miquel  Middle-blocker    187
# 173     12      Corona Mediavilla Fabián        Receptor    185
# 174     13  Calzón Algaba Francisco José  Middle-blocker    198
# 175     14  Frías Collado Juan Francisco  Middle-blocker    198
# 176     17     Rodríguez Bonilla Roberto        Receptor    190
#
#     Año_de_nacimiento Alcance_en_ataque Alcance_en_bloqueo  id_jugador  \
# 0                1997               310                300         200
# 1                2002               330                322         201
# 2                1990               330                320         202
# 3                1999               337                323         203
# 4                1999               295                268         204
# ..                ...               ...                ...         ...
# 172              2001               325                315         372
# 173              2003               310                305         373
# 174              1992               330                320         374
# 175              2000               325                315         375
# 176              2000               335                320         376
#
#      temporada
# 0    2022-2023
# 1    2022-2023
# 2    2022-2023
# 3    2022-2023
# 4    2022-2023
# ..         ...
# 172  2022-2023
# 173  2022-2023
# 174  2022-2023
# 175  2022-2023
# 176  2022-2023
#
# [177 rows x 9 columns]

# %%
liberos = pd.merge(libero, df[['Nombre', 'id_jugador']], on='Nombre', how='left')

liberos
# Out:
#                                Nombre Partidos_jugados Sets_jugados  \
# 0                 Larrañaga Ledo Unai               26           90
# 1                 Conde Barrios Lucas                1            3
# 2                  Masia Porres Arnau               24           84
# 3                 Osado Carrasco José               22           83
# 4                         Ruiz Daniel               23           70
# 5            Ruda Martínez Florentino                1            4
# 6           Fernández Rojas Alejandro               16           41
# 7      San Martín Rodríguez Alejandro               30          109
# 8                Gámiz Padilla Aharón               28          102
# 9                 Sánchez Cano Víctor               21           70
# 10  Fernández Martínez Francisco José               20           74
# 11  Fernández Martínez Francisco José               20           74
# 12             Piris Guiscafré Antoni               21           74
# 13             Mengod Bautista Javier               24           87
# 14           Barrasa Portomeñe Samuel               15           46
# 15                Alves Castro Adrián               22           71
# 16          Giustiniano Mariano Ariel                1            3
# 17               Redonda Camaño David                1            3
# 18       Giménez Hernández José María                5           17
# 19         Gallardo Hernández Rodrigo               19           53
# 20            Iborra Ballester Héctor                5           11
#
#    Recepciones Recepciones_exitosas Recepciones_fallidas  \
# 0          232                   32                   18
# 1           11                    0                    0
# 2          196                   31                   15
# 3          236                   27                   20
# 4          130                   12                   13
# 5           16                    5                    0
# 6           55                   12                    0
# 7          169                   38                   31
# 8          152                   22                   47
# 9          141                   28                   10
# 10         141                   24                   51
# 11         141                   24                   51
# 12         173                   44                   12
# 13         216                   40                   89
# 14          92                   18                   15
# 15         177                   48                   11
# 16           5                    2                    0
# 17           5                    0                    0
# 18          27                    6                   13
# 19          73                   24                    9
# 20          16                    6                    5
#
#    Recepciones_otro_jugador Puntos_perdidos_recep Puntos_ganados_recep  \
# 0                        14                    67                   94
# 1                         1                     7                    6
# 2                        21                    78                  118
# 3                        34                    96                  181
# 4                        21                    60                  102
# 5                         1                     8                    5
# 6                         8                    20                   28
# 7                         9                    71                  155
# 8                        16                    70                  136
# 9                        22                    56                  107
# 10                       17                    88                  112
# 11                       17                    88                  112
# 12                       27                    90                  108
# 13                       27                   158                  164
# 14                       15                    60                   77
# 15                       30                   111                   95
# 16                        0                     7                    1
# 17                        2                     3                    6
# 18                        4                    17                   28
# 19                       20                    68                   86
# 20                        6                    23                   18
#
#    Total_puntos_recep Recep_Ranking  id_jugador
# 0                 457        0,4070         303
# 1                  25        0,4000         275
# 2                 459        0,3137         218
# 3                 594        0,2946         237
# 4                 338        0,2870         263
# 5                  35        0,2857         292
# 6                 123        0,2846         261
# 7                 473        0,2579         322
# 8                 443        0,2573         312
# 9                 364        0,2500         369
# 10                433        0,2309         229
# 11                433        0,2309         360
# 12                454        0,2247         254
# 13                694        0,2147         289
# 14                277        0,2130         206
# 15                472        0,2097         330
# 16                 15        0,2000         300
# 17                 16        0,1875         363
# 18                 95        0,1789         362
# 19                280        0,1036         204
# 20                 74        0,0541         286

# %%
liberos['temporada'] = '2022-2023'

# %%
liberos = pd.merge(libero, df[['Nombre', 'id_jugador']], on='Nombre', how='left')

convertir = liberos.columns.difference(['Nombre'])
liberos['Recep_Ranking'] = liberos['Recep_Ranking'].str.replace(',', '.').astype(float)
liberos[convertir] = liberos[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
liberos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre                    21 non-null     object
#  1   Partidos_jugados          21 non-null     int64
#  2   Sets_jugados              21 non-null     int64
#  3   Recepciones               21 non-null     int64
#  4   Recepciones_exitosas      21 non-null     int64
#  5   Recepciones_fallidas      21 non-null     int64
#  6   Recepciones_otro_jugador  21 non-null     int64
#  7   Puntos_perdidos_recep     21 non-null     int64
#  8   Puntos_ganados_recep      21 non-null     int64
#  9   Total_puntos_recep        21 non-null     int64
#  10  Recep_Ranking             21 non-null     float64
#  11  id_jugador                21 non-null     int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## Guardado en CSV.

# %%
liberos.to_csv('../../data/2022-2023/liberos.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyball_database')

# %%
dtype = {'id_jugador': Integer}
liberos.to_sql('libero', engine, if_exists='append', index=False, dtype=dtype)
# Out:
# 21
