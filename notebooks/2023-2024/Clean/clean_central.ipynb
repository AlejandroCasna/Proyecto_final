# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.funciones import *

# %%
resultado = scraping_central('https://www.rfevb.com/')
# Out:
# Scraping exitoso

# %%
resultado[3:22]
# Out:
# ['Romaní Leandro Gustavo',
#  '(Conectabalear CV Manacor)',
#  '8',
#  '26',
#  '17',
#  '5',
#  '1',
#  '25',
#  '11',
#  '14',
#  '5',
#  '89',
#  '71',
#  '15',
#  '7',
#  '131',
#  '2,1923',
#  '2',
#  'Da Cruz Neto Walter']

# %%
resultado = [resultado[i:i+18] for i in range(3, len(resultado), 18)]

central = pd.DataFrame(resultado)

'''Cuidado con la modificación de columnas, drops y demas. puede cambiar.'''

    
column_names = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Bloqueos', 'Bloqueo_exitoso',
                'Bloqueo_fallido', 'Total_bloqueos', 'Saque',
                'Errores_Saque', 'Porcentaje_error', 'Total_saques', 'Ataque_exitoso','Errores_ataque','Porc_error',
                'Total_ataques','Ataque_Ranking',2]


central.columns = column_names
central.drop(1, inplace=True, axis=1)
central.drop(2, inplace=True, axis=1)
central.drop(11, inplace=True)

# %%
central.head()
# Out:
#                      Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0    Romaní Leandro Gustavo                8           26       17
# 1       Da Cruz Neto Walter                5           19       15
# 2  Macarro Tortajada Daniel                9           35       20
# 3     Méndez Jiménez Víctor                9           34       30
# 4   Dos Santos Cezar Moises                9           38       31
#
#   Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0               5               1             25    11            14
# 1               3               0             18     0             7
# 2               9               0             41     6            21
# 3              18               0             62     0            10
# 4              24               0             66     1            15
#
#   Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                5           89             71             15          7
# 1                2           68             38              1          8
# 2                4          137             77              9          5
# 3                4          123             63              6          7
# 4                2           85             77             10          9
#
#   Total_ataques Ataque_Ranking
# 0           131         2,1923
# 1            67         1,7895
# 2           121         1,6857
# 3           119         1,5294
# 4           132         1,3421

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../../data/2023-2024/Jugadores.csv')
df
# Out:
#       #                          Nombre        Posición Altura  \
# 0     2          Paradela Cortón Miguel          Líbero      -
# 1     3           Bouza Ferreiro Víctor        Receptor      -
# 2     4               Linares José Luis         Opuesto      -
# 3     5        Barrasa Portomeñe Samuel          Líbero      -
# 4     6           Edward Batalla Dexter     Colocador/a      -
# ..   ..                             ...             ...    ...
# 163  15              Marí Domene Álvaro  Middle-blocker    198
# 164  17           Martínez Gómez Sergio         Opuesto    190
# 165  20  Hernández Robeff Tomás Agustín        Receptor    190
# 166  23          Jiménez Gallego Carlos        Receptor    193
# 167  77   Fernández Rodríguez Francisco        Receptor      -
#
#     Año de nacimiento Alcance en ataque Alcance en bloqueo  id_jugador
# 0                2004                 -                  -           1
# 1                1990                 -                  -           2
# 2                1998                 -                  -           3
# 3                2007                 -                  -           4
# 4                2000                 -                  -           5
# ..                ...               ...                ...         ...
# 163              2002               333                315         164
# 164              2002               329                309         165
# 165              1998               329                308         166
# 166              1995               346                320         167
# 167              1996                 -                  -         168
#
# [168 rows x 8 columns]

# %%
central = pd.merge(central, df[['Nombre', 'id_jugador']], on='Nombre', how='left')

central
# Out:
#                       Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0     Romaní Leandro Gustavo                8           26       17
# 1        Da Cruz Neto Walter                5           19       15
# 2   Macarro Tortajada Daniel                9           35       20
# 3      Méndez Jiménez Víctor                9           34       30
# 4    Dos Santos Cezar Moises                9           38       31
# 5            Seybering David                8           34       13
# 6      Flores Fabian Emanuel                9           35       26
# 7      Saxton Vigrass Graham                3            7        4
# 8            Ruiz Mira Borja                9           29        8
# 9      Téllez Rodríguez Axel                6           18       12
# 10  Allen Serrano Luis Vidal                9           23        8
#
#    Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0                5               1             25    11            14
# 1                3               0             18     0             7
# 2                9               0             41     6            21
# 3               18               0             62     0            10
# 4               24               0             66     1            15
# 5               20               0             50     8            15
# 6               39               0            116     1             9
# 7                2               0             14     0             2
# 8               25               0             56     6            22
# 9               19               1             44     2            14
# 10              28               0             49     1             8
#
#    Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                 5           89             71             15          7
# 1                 2           68             38              1          8
# 2                 4          137             77              9          5
# 3                 4          123             63              6          7
# 4                 2           85             77             10          9
# 5                 3          106             71              5          7
# 6                 2          110             75              5          6
# 7                 1           19             12              3          1
# 8                 8          107             66              5          5
# 9                 1           61             31              8          3
# 10                0           52             38              5          9
#
#    Total_ataques Ataque_Ranking  id_jugador
# 0            131         2,1923          48
# 1             67         1,7895         154
# 2            121         1,6857          21
# 3            119         1,5294         117
# 4            132         1,3421          86
# 5            119         1,3235          28
# 6            108         1,2286          98
# 7             21         1,1429          56
# 8            102         0,7931         139
# 9             54         0,0000         120
# 10            73        -0,1304         144

# %% [markdown]
# ## Por precaución lo guardamos en CSV

# %%
central.to_csv('..\..\data\jugadores\central.csv', index=False)

# %% [markdown]
# ## Vamos a pasar todo a una base de datos!

# %%
with open('../../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/proyecto_final')

# %%
dtype = {'id_jugador': Integer}
central.to_sql('centrales', engine, if_exists='append', index=False, dtype=dtype)
# Out:
# 11
