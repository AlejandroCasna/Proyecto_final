# %%
import sys
sys.path.append('C:\ironhack\Proyecto_final') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=124&PID=152'
parametro = 'estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Bloqueos', 'Bloqueo_exitoso',
                'Bloqueo_fallido', 'Total_bloqueos', 'Saque',
                'Errores_Saque', 'Porcentaje_error', 'Total_saques', 'Ataque_exitoso','Errores_ataque','Porc_error',
                'Total_ataques','Ataque_Ranking',2]

parametro= 'estadistica_central'

central = crear_df(datos[4],columna,parametro)
central.drop([1,2], inplace=True, axis=1)
central.head(2)
# Out:
#                    Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0  Romaní Leandro Gustavo                8           26       17
# 1     Da Cruz Neto Walter                5           19       15
#
#   Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0               5               1             25    11            14
# 1               3               0             18     0             7
#
#   Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                5           89             71             15          7
# 1                2           68             38              1          8
#
#   Total_ataques Ataque_Ranking
# 0           131         2,1923
# 1            67         1,7895

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../../data/2023-2024/Jugadores.csv')
df.head(2)
# Out:
#    Dorsal                  Nombre  Posición  Altura  Año_de_nacimiento  \
# 0       2  Paradela Cortón Miguel    Líbero     0.0               2004
# 1       3   Bouza Ferreiro Víctor  Receptor     0.0               1990
#
#    Alcance_en_ataque  Alcance_en_bloqueo   id_jugador  temporada    id_equipo
# 0                0.0                 0.0  1-2023-2024  2023-2024  1-2023-2024
# 1                0.0                 0.0  2-2023-2024  2023-2024  1-2023-2024

# %%
central = pd.merge(central, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')
central['temporada']='2022-2023'
central
# Out:
#                       Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0     Romaní Leandro Gustavo                8           26       17
# 1        Da Cruz Neto Walter                5           19       15
# 2   Macarro Tortajada Daniel                9           35       20
# 3      Méndez Jiménez Víctor                9           34       30
# 4    Dos Santos Cezar Moises                9           38       31
# 5            Seybering David                8           34       13
# 6      Flores Fabian Emanuel                9           35       26
# 7      Saxton Vigrass Graham                3            7        4
# 8            Ruiz Mira Borja                9           29        8
# 9      Téllez Rodríguez Axel                6           18       12
# 10  Allen Serrano Luis Vidal                9           23        8
#
#    Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0                5               1             25    11            14
# 1                3               0             18     0             7
# 2                9               0             41     6            21
# 3               18               0             62     0            10
# 4               24               0             66     1            15
# 5               20               0             50     8            15
# 6               39               0            116     1             9
# 7                2               0             14     0             2
# 8               25               0             56     6            22
# 9               19               1             44     2            14
# 10              28               0             49     1             8
#
#    Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                 5           89             71             15          7
# 1                 2           68             38              1          8
# 2                 4          137             77              9          5
# 3                 4          123             63              6          7
# 4                 2           85             77             10          9
# 5                 3          106             71              5          7
# 6                 2          110             75              5          6
# 7                 1           19             12              3          1
# 8                 8          107             66              5          5
# 9                 1           61             31              8          3
# 10                0           52             38              5          9
#
#    Total_ataques Ataque_Ranking     id_jugador     id_equipo  temporada
# 0            131         2,1923   48-2023-2024   4-2023-2024  2022-2023
# 1             67         1,7895  154-2023-2024  12-2023-2024  2022-2023
# 2            121         1,6857   21-2023-2024   2-2023-2024  2022-2023
# 3            119         1,5294  117-2023-2024   9-2023-2024  2022-2023
# 4            132         1,3421   86-2023-2024   6-2023-2024  2022-2023
# 5            119         1,3235   28-2023-2024   3-2023-2024  2022-2023
# 6            108         1,2286   98-2023-2024   8-2023-2024  2022-2023
# 7             21         1,1429   56-2023-2024   5-2023-2024  2022-2023
# 8            102         0,7931  139-2023-2024  10-2023-2024  2022-2023
# 9             54         0,0000  120-2023-2024   9-2023-2024  2022-2023
# 10            73        -0,1304  144-2023-2024  11-2023-2024  2022-2023

# %%
convertir = central.columns.difference(['Nombre','id_jugador','id_equipo','temporada'])
central['Ataque_Ranking'] = central['Ataque_Ranking'].str.replace(',', '.').astype(float)
central[convertir] = central[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
central.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nombre            11 non-null     object
#  1   Partidos_jugados  11 non-null     int64
#  2   Sets_jugados      11 non-null     int64
#  3   Bloqueos          11 non-null     int64
#  4   Bloqueo_exitoso   11 non-null     int64
#  5   Bloqueo_fallido   11 non-null     int64
#  6   Total_bloqueos    11 non-null     int64
#  7   Saque             11 non-null     int64
#  8   Errores_Saque     11 non-null     int64
#  9   Porcentaje_error  11 non-null     int64
#  10  Total_saques      11 non-null     int64
#  11  Ataque_exitoso    11 non-null     int64
#  12  Errores_ataque    11 non-null     int64
#  13  Porc_error        11 non-null     int64
#  14  Total_ataques     11 non-null     int64
#  15  Ataque_Ranking    11 non-null     float64
#  16  id_jugador        11 non-null     object
#  17  id_equipo         11 non-null     object
#  18  temporada         11 non-null     object
# dtypes: float64(1), int64(14), object(4)
# memory usage: 1.8+ KB

# %%
normalizar('../../../Data/2023-2024/central.csv')
# Out:
#                       Nombre  Partidos_jugados  Sets_jugados  Bloqueos  \
# 0     Romani Leandro Gustavo                 8            26        17
# 1        Da Cruz Neto Walter                 5            19        15
# 2   Macarro Tortajada Daniel                 9            35        20
# 3      Mendez Jimenez Victor                 9            34        30
# 4    Dos Santos Cezar Moises                 9            38        31
# 5            Seybering David                 8            34        13
# 6      Flores Fabian Emanuel                 9            35        26
# 7      Saxton Vigrass Graham                 3             7         4
# 8            Ruiz Mira Borja                 9            29         8
# 9      Tellez Rodriguez Axel                 6            18        12
# 10  Allen Serrano Luis Vidal                 9            23         8
#
#     Bloqueo_exitoso  Bloqueo_fallido  Total_bloqueos  Saque  Errores_Saque  \
# 0                 5                1              25     11             14
# 1                 3                0              18      0              7
# 2                 9                0              41      6             21
# 3                18                0              62      0             10
# 4                24                0              66      1             15
# 5                20                0              50      8             15
# 6                39                0             116      1              9
# 7                 2                0              14      0              2
# 8                25                0              56      6             22
# 9                19                1              44      2             14
# 10               28                0              49      1              8
#
#     Porcentaje_error  Total_saques  Ataque_exitoso  Errores_ataque  \
# 0                  5            89              71              15
# 1                  2            68              38               1
# 2                  4           137              77               9
# 3                  4           123              63               6
# 4                  2            85              77              10
# 5                  3           106              71               5
# 6                  2           110              75               5
# 7                  1            19              12               3
# 8                  8           107              66               5
# 9                  1            61              31               8
# 10                 0            52              38               5
#
#     Porc_error  Total_ataques  Ataque_Ranking     id_jugador     id_equipo  \
# 0            7            131          2.1923   48-2023-2024   4-2023-2024
# 1            8             67          1.7895  154-2023-2024  12-2023-2024
# 2            5            121          1.6857   21-2023-2024   2-2023-2024
# 3            7            119          1.5294  117-2023-2024   9-2023-2024
# 4            9            132          1.3421   86-2023-2024   6-2023-2024
# 5            7            119          1.3235   28-2023-2024   3-2023-2024
# 6            6            108          1.2286   98-2023-2024   8-2023-2024
# 7            1             21          1.1429   56-2023-2024   5-2023-2024
# 8            5            102          0.7931  139-2023-2024  10-2023-2024
# 9            3             54          0.0000  120-2023-2024   9-2023-2024
# 10           9             73         -0.1304  144-2023-2024  11-2023-2024
#
#     temporada
# 0   2022-2023
# 1   2022-2023
# 2   2022-2023
# 3   2022-2023
# 4   2022-2023
# 5   2022-2023
# 6   2022-2023
# 7   2022-2023
# 8   2022-2023
# 9   2022-2023
# 10  2022-2023

# %% [markdown]
# ## Guardado en CSV.

# %%
central.to_csv('../../../data/2023-2024/central.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
dtype = {'id_jugador': Integer}
central.to_sql('central', engine, if_exists='append', index=False, dtype=dtype)
# Out:
# 11
