# %%
import sys
sys.path.append("C:\ironhack\Proyecto_final") 
from src.funciones import *

# %%
equipo22 = pd.read_csv('../data/2022-2023/equipo.csv')
equipo23 = pd.read_csv('../data/2023-2024/Equipos.csv')
equipo21 = pd.read_csv('../data/2021-2022/Equipo.csv')
equipo20 = pd.read_csv('../data/2020-2021/Equipo.csv')
equipo19 = pd.read_csv('../data/2019-2020/Equipo.csv')

# %%
df_concatenado = pd.concat([equipo23, equipo22,equipo21,equipo20,equipo19], ignore_index=True)
df_concatenado
ar = df_concatenado.Equipo.unique()
df = pd.DataFrame(ar)
df['NuevaColumna'] = df.index + 1

# %%
df.columns = ['Equipo', 'id_equipo']
df
# Out:
#                        Equipo  id_equipo
# 0                Arenal Emeve          1
# 1              Cisneros Alter          2
# 2                 Voley Palma          3
# 3                     Manacor          4
# 4                     Guaguas          5
# 5                  CV Melilla          6
# 6                CV San Roque          7
# 7             Rio Duero Soria          8
# 8                   CV Teruel          9
# 9             Unicaja Almeria         10
# 10       Conqueridor Valencia         11
# 11          CV Villena Petrer         12
# 12             Barca Voleibol         13
# 13              Rotogal Boiro         14
# 14  Voley Textil Santanderina         15
# 15                     Intasa         16
# 16                Ibiza Voley         17
# 17                       Grau         18
# 18          Voleibol Almoradi         19
# 19      Vecindario Las Palmas         20

# %%
df.loc[0, 'informacion']='''\nDatos de contacto:
\nTlf: 670553183\n
\nEmail: clubemevelugo@gmail.com
\nPabellón Municipal de Deportes
\nRua Santiago S/N
\n27002 - Lugo   Galicia
\nEl Club Voleibol Emevé, cuyas siglas significan El Mejor Equipo de Voleibol de España, es un equipo de voleibol de la ciudad de Lugo situado en Galicia. Fue fundado en 1983 actualmente cuenta con un equipo en Superliga Masculina y en Superliga Femenina siendo a día de hoy el único club de España con dos equipos en la máxima categoría. El Club Voleibol Emevé es un club de formación que trabaja en la ciudad de Lugo con un número de jugadores y jugadoras que superan los 400 niños y niñas. Es un club que potencia y fomenta la igualdad, no en vano los puestos de responsabilidad de la directiva están ocupados por tres mujeres.'''

df.loc[1,'informacion']='''\nDatos de contacto:
\nTlf: 618253715
\nEmail: gerencia@cdcisnerosalter.com / comunicaciones@cdcisnerosalter.com / info@cdcisnerosalter.com
\nWeb: www.cdcisnerosalter.com
\nCalle Bentejui, 11, 38320 San Cristóbal de La Laguna. Santa Cruz de Tenerife. Canarias. España
\nEl Club Deportivo Cisneros Alter (CDCA) de Tenerife es una entidad deportiva sin ánimo de lucro que fue constituida en septiembre de 2013 por un grupo de profesores y monitores del Colegio Cisneros Alter con la finalidad de desarrollar un proyecto de fomento de diferentes modalidades deportivas más allá de la actividad del centro educativo. '''

