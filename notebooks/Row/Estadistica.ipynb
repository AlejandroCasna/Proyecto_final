# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('estadisticas_por_equipo.csv')
df
# Out:
#                       Equipo Jugados Jugados.1 Puntos Puntos.1 Puntos.2  \
# 0                        NaN       P         S    Tot       BP        G
# 1          Grupo Herce Soria       7        24    456      171      285
# 2    UPV Leleman Conqueridor       7        29    455      172      283
# 3           Club Vóley Palma       7        26    447      160      287
# 4             Cisneros Alter       7        27    443      143      300
# 5               CV San Roque       7        29    437      151      286
# 6     Pamesa Teruel Voleibol       7        28    428      153      275
# 7   Unicaja Costa de Almería       7        23    406      163      243
# 8   Conectabalear CV Manacor       7        24    375      139      236
# 9               Arenal Emevé       7        24    374      108      266
# 10                CV Guaguas       6        22    362      152      210
# 11                CV Melilla       6        21    355      125      230
# ...

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#                       Equipo Jugados Jugados.1 Puntos Puntos.1 Puntos.2  \
# 1          Grupo Herce Soria       7        24    456      171      285
# 2    UPV Leleman Conqueridor       7        29    455      172      283
# 3           Club Vóley Palma       7        26    447      160      287
# 4             Cisneros Alter       7        27    443      143      300
# 5               CV San Roque       7        29    437      151      286
# 6     Pamesa Teruel Voleibol       7        28    428      153      275
# 7   Unicaja Costa de Almería       7        23    406      163      243
# 8   Conectabalear CV Manacor       7        24    375      139      236
# 9               Arenal Emevé       7        24    374      108      266
# 10                CV Guaguas       6        22    362      152      210
# 11                CV Melilla       6        21    355      125      230
# 12      Volei Villena Petrer       7        25    336       96      240
#
# ...

# %%
columnas_a_excluir = ['Equipo']
df[df.columns.difference(columnas_a_excluir)] = df[df.columns.difference(columnas_a_excluir)].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 1 to 12
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Equipo       12 non-null     object
#  1   Jugados      12 non-null     int64
#  2   Jugados.1    12 non-null     int64
#  3   Puntos       12 non-null     int64
#  4   Puntos.1     12 non-null     int64
#  5   Puntos.2     12 non-null     int64
#  6   Puntos.3     12 non-null     int64
#  7   Saque        12 non-null     int64
#  8   Saque.1      12 non-null     int64
#  9   Saque.2      12 non-null     int64
#  10  Saque.3      12 non-null     float64
#  11  Saque.4      12 non-null     int64
#  12  Recepcion    12 non-null     int64
#  13  Recepcion.1  12 non-null     int64
#  14  Recepcion.2  12 non-null     int64
#  15  Recepcion.3  12 non-null     int64
#  16  Recepcion.4  12 non-null     int64
#  17  Recepcion.5  12 non-null     int64
#  18  Ataque       12 non-null     int64
# ...

# %%
df.to_csv('estadisticas_int.csv', index=False)
