# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import multiprocessing as mp
from joblib import Parallel, delayed
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
from sqlalchemy import create_engine

# %%
opciones=Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--incognito')
opciones.add_argument('--start-maximized')

# %%
url = 'https://www.rfevb.com/competiciones/superliga-masculina'
driver = webdriver.Chrome(options = opciones)
driver.get(url)

# %%
# Click cookies
driver.find_element(By.XPATH , '//*[@id="lnkCookie"]').click()

# %%
# Entramos en plantilla
driver.find_element(By.XPATH , '//*[@id="miWrapper"]/ul/li[2]/ul/li[1]/a').click()

# %%
equipos = driver.find_elements(By.CLASS_NAME, 'rlvI')[0:12]
# Verificamos que los que nos devuelve son datos de mas entonces reiniciamos la lista con los elementos que nos interesa.

# %%
superLiga_Masculino=[]
for i in range(12):
    
    e = driver.find_elements(By.CLASS_NAME, 'rlvI')[i]
    
    print(e.text)
    
    e.click()
    
    print('Estoy dentro.')
    
    time.sleep(2)
   
    superLiga_Masculino.append(driver.find_elements(By.CLASS_NAME , 't-row')[3].text.split('\n'))
    
    print('Extraigo')
    
    time.sleep(2)
    
    driver.get('https://rfevb-web.dataproject.com/CompetitionTeamSearch.aspx?ID=124')
    
    time.sleep(2)
# Out:
# Arenal Emevé
# Estoy dentro.
# Extraigo
# Cisneros Alter
# Estoy dentro.
# Extraigo
# Club Vóley Palma
# Estoy dentro.
# Extraigo
# Conectabalear CV Manacor
# Estoy dentro.
# Extraigo
# CV Guaguas
# Estoy dentro.
# Extraigo
# CV Melilla
# Estoy dentro.
# Extraigo
# CV San Roque
# Estoy dentro.
# Extraigo
# Grupo Herce Soria
# Estoy dentro.
# Extraigo
# Pamesa Teruel Voleibol
# Estoy dentro.
# Extraigo
# Unicaja Costa de Almería
# Estoy dentro.
# Extraigo
# UPV Leleman Conqueridor
# Estoy dentro.
# Extraigo
# Volei Villena Petrer
# Estoy dentro.
# Extraigo

# %%
superLiga_Masculino[0]
# Out:
# ['#',
#  'Nombre',
#  'Posición',
#  'Año de nacimiento',
#  '2',
#  'Paradela Cortón Miguel',
#  'Líbero',
#  '2004',
#  '3',
#  'Bouza Ferreiro Víctor',
#  'Receptor',
#  '1990',
#  '4',
#  'Linares José Luis',
#  'Opuesto',
#  '1998',
#  '5',
#  'Barrasa Portomeñe Samuel',
#  'Líbero',
#  '2007',
#  '6',
#  'Edward Batalla Dexter',
#  'Colocador/a',
#  '2000',
#  '9',
#  'Schulz Max',
#  'Receptor',
#  '2002',
#  '10',
#  'Biliato Luca',
#  'Opuesto',
#  '1993',
#  '11',
#  'Villar Álvarez Pablo',
#  'Colocador/a',
#  '2002',
#  '12',
#  'Rodríguez Rubio Aurelio',
#  'Middle-blocker',
#  '2000',
#  '13',
#  'Frías Collado Juan Francisco',
#  'Middle-blocker',
#  '2000',
#  '14',
#  'Augustinho De Lara Sopschuk Luis Henrique',
#  'Middle-blocker',
#  '2002',
#  '17',
#  'Ossola Gude Nahuel',
#  'Receptor',
#  '2002']

# %% [markdown]
# # Prueba

# %%
superLiga_Masculino[0][0:4]
# Out:
# ['#', 'Nombre', 'Posición', 'Año de nacimiento']

# %%
superLiga_Masculino[0][4:]
# Out:
# ['2',
#  'Paradela Cortón Miguel',
#  'Líbero',
#  '2004',
#  '3',
#  'Bouza Ferreiro Víctor',
#  'Receptor',
#  '1990',
#  '4',
#  'Linares José Luis',
#  'Opuesto',
#  '1998',
#  '5',
#  'Barrasa Portomeñe Samuel',
#  'Líbero',
#  '2007',
#  '6',
#  'Edward Batalla Dexter',
#  'Colocador/a',
#  '2000',
#  '9',
#  'Schulz Max',
#  'Receptor',
#  '2002',
#  '10',
#  'Biliato Luca',
#  'Opuesto',
#  '1993',
#  '11',
#  'Villar Álvarez Pablo',
#  'Colocador/a',
#  '2002',
#  '12',
#  'Rodríguez Rubio Aurelio',
#  'Middle-blocker',
#  '2000',
#  '13',
#  'Frías Collado Juan Francisco',
#  'Middle-blocker',
#  '2000',
#  '14',
#  'Augustinho De Lara Sopschuk Luis Henrique',
#  'Middle-blocker',
#  '2002',
#  '17',
#  'Ossola Gude Nahuel',
#  'Receptor',
#  '2002']

# %%
# Definir las columnas y los datos
columns = superLiga_Masculino[0][0:4]
data = superLiga_Masculino[0][4:]

# Dividir los datos en lotes de 4 (ya que cada jugador tiene 4 atributos)
player_data = [data[i:i+4] for i in range(0, len(data), 4)]

# Crear el DataFrame
Arenal_Emeve = pd.DataFrame(player_data, columns=columns)

Arenal_Emeve = Arenal_Emeve.rename(columns={'#': 'Dorsal'})
Arenal_Emeve
# Out:
#    Dorsal                                     Nombre        Posición  \
# 0       2                     Paradela Cortón Miguel          Líbero
# 1       3                      Bouza Ferreiro Víctor        Receptor
# 2       4                          Linares José Luis         Opuesto
# 3       5                   Barrasa Portomeñe Samuel          Líbero
# 4       6                      Edward Batalla Dexter     Colocador/a
# 5       9                                 Schulz Max        Receptor
# 6      10                               Biliato Luca         Opuesto
# 7      11                       Villar Álvarez Pablo     Colocador/a
# 8      12                    Rodríguez Rubio Aurelio  Middle-blocker
# 9      13               Frías Collado Juan Francisco  Middle-blocker
# 10     14  Augustinho De Lara Sopschuk Luis Henrique  Middle-blocker
# 11     17                         Ossola Gude Nahuel        Receptor
#
#    Año de nacimiento
# 0               2004
# 1               1990
# 2               1998
# 3               2007
# 4               2000
# 5               2002
# 6               1993
# 7               2002
# 8               2000
# 9               2000
# 10              2002
# 11              2002

# %% [markdown]
# # definimos DataFrame jugadores completo

# %%
Jugadores = pd.DataFrame()

# Iterar a través de las 12 sub-listas
for sublist in superLiga_Masculino:
    # Definir las columnas y los datos
    columns = sublist[0:4]
    data = sublist[4:]
    
    # Dividir los datos en lotes de 4 (ya que cada jugador tiene 4 atributos)
    player_data = [data[i:i+4] for i in range(0, len(data), 4)]
    
    # Crear un DataFrame temporal para esta sub-lista
    temp_df = pd.DataFrame(player_data, columns=columns)
    
    # Cambiar el nombre de la columna '#'
    temp_df = temp_df.rename(columns={'#': 'Dorsal'})
    
    # Concatenar el DataFrame temporal con el DataFrame principal
    Jugadores = pd.concat([Jugadores, temp_df], ignore_index=True)

# Mostrar el DataFrame final
Jugadores
# Out:
#     Dorsal                          Nombre        Posición Año de nacimiento
# 0        2          Paradela Cortón Miguel          Líbero              2004
# 1        3           Bouza Ferreiro Víctor        Receptor              1990
# 2        4               Linares José Luis         Opuesto              1998
# 3        5        Barrasa Portomeñe Samuel          Líbero              2007
# 4        6           Edward Batalla Dexter     Colocador/a              2000
# ..     ...                             ...             ...               ...
# 163     15              Marí Domene Álvaro  Middle-blocker              2002
# 164     17           Martínez Gómez Sergio         Opuesto              2002
# 165     20  Hernández Robeff Tomás Agustín        Receptor              1998
# 166     23          Jiménez Gallego Carlos        Receptor              1995
# 167     77   Fernández Rodríguez Francisco        Receptor              1996
#
# [168 rows x 4 columns]

# %%
Jugadores['ID'] = Jugadores.index + 1
Jugadores
# Out:
#     Dorsal                          Nombre        Posición Año de nacimiento  \
# 0        2          Paradela Cortón Miguel          Líbero              2004
# 1        3           Bouza Ferreiro Víctor        Receptor              1990
# 2        4               Linares José Luis         Opuesto              1998
# 3        5        Barrasa Portomeñe Samuel          Líbero              2007
# 4        6           Edward Batalla Dexter     Colocador/a              2000
# ..     ...                             ...             ...               ...
# 163     15              Marí Domene Álvaro  Middle-blocker              2002
# 164     17           Martínez Gómez Sergio         Opuesto              2002
# 165     20  Hernández Robeff Tomás Agustín        Receptor              1998
# 166     23          Jiménez Gallego Carlos        Receptor              1995
# 167     77   Fernández Rodríguez Francisco        Receptor              1996
#
#       ID
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 163  164
# 164  165
# 165  166
# 166  167
# 167  168
#
# [168 rows x 5 columns]

# %% [markdown]
# # pasamos este archivo a SQL.

# %%
with open('pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\ironhack\Semana-4\Proyecto-scraping\Jupyter\SuperLiga_Masculina.ipynb Celda 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/ironhack/Semana-4/Proyecto-scraping/Jupyter/SuperLiga_Masculina.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> with open('pass.txt', 'r') as file:   # pass.txt en .gitignore
#       <a href='vscode-notebook-cell:/c%3A/ironhack/Semana-4/Proyecto-scraping/Jupyter/SuperLiga_Masculina.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     pass_ = file.read()
#
# File c:\Users\Alejandro\anaconda3\envs\clase\lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pass.txt'

# %%
from sqlalchemy import create_engine

# Establece una conexión para crear la base de datos
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)

# Crea un motor para la base de datos FenixClub
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/FenixClub')

# %%
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/FenixClub')

# %%
Jugadores.to_sql('jugadores', con=engine, if_exists='replace', index=False)

# %%
Jugadores.to_csv('Jugadores.csv', index=False)

# %% [markdown]
# # Extraigamos datos de cada equipo

# %%
url = 'https://www.rfevb.com/competiciones/superliga-masculina'
driver = webdriver.Chrome(options = opciones)
driver.get(url)

# %%
# Click cookies
driver.find_element(By.XPATH , '//*[@id="lnkCookie"]').click()

# %%
# Entramos en plantilla
driver.find_element(By.XPATH , '//*[@id="miWrapper"]/ul/li[2]/ul/li[1]/a').click()

# %%
equipos = driver.find_elements(By.CLASS_NAME, 'rlvI')[0:12]
# Verificamos que los que nos devuelve son datos de mas entonces reiniciamos la lista con los elementos que nos interesa.

# %%
datos = []

for i in range(len(equipos)):
    e = driver.find_elements(By.CLASS_NAME, 'rlvI')[i]
    nombre_equipo = e.text  # Obtén el nombre del equipo
    
    print(nombre_equipo)  # Imprime el nombre del equipo
    
    e.click()
    print('Estoy dentro.')
    #time.sleep(2)
    
    informacion_equipo = driver.find_element(By.XPATH ,'//*[@id="Content_Main_TeamInfo_Address"]').text.split('\n')
    
    # Agrega el nombre del equipo a la lista de información del equipo
    informacion_equipo.insert(0, nombre_equipo)
    
    datos.append(informacion_equipo)
    print('Extraigo')
    
    #time.sleep(2)
    driver.get('https://rfevb-web.dataproject.com/CompetitionTeamSearch.aspx?ID=124')
    #time.sleep(2)
# Out:
# Arenal Emevé
# Estoy dentro.
# Extraigo
# Cisneros Alter
# Estoy dentro.
# Extraigo
# Club Vóley Palma
# Estoy dentro.
# Extraigo
# Conectabalear CV Manacor
# Estoy dentro.
# Extraigo
# CV Guaguas
# Estoy dentro.
# Extraigo
# CV Melilla
# Estoy dentro.
# Extraigo
# CV San Roque
# Estoy dentro.
# Extraigo
# Grupo Herce Soria
# Estoy dentro.
# Extraigo
# Pamesa Teruel Voleibol
# Estoy dentro.
# Extraigo
# Unicaja Costa de Almería
# Estoy dentro.
# Extraigo
# UPV Leleman Conqueridor
# Estoy dentro.
# Extraigo
# Volei Villena Petrer
# Estoy dentro.
# Extraigo

# %%
datos_formateados = []
for sublista in datos:
    nombre_equipo = sublista[0]
    contacto = ", ".join(sublista[2:5])  # Convierte la lista en una cadena de texto
    
    
    datos_formateados.append([nombre_equipo, contacto])

# Crea un DataFrame a partir de los datos formateados
df = pd.DataFrame(datos_formateados, columns=["Equipo", "Datos de contacto"])

# %%
df
# Out:
#                       Equipo  \
# 0               Arenal Emevé
# 1             Cisneros Alter
# 2           Club Vóley Palma
# 3   Conectabalear CV Manacor
# 4                 CV Guaguas
# 5                 CV Melilla
# 6               CV San Roque
# 7          Grupo Herce Soria
# 8     Pamesa Teruel Voleibol
# 9   Unicaja Costa de Almería
# 10   UPV Leleman Conqueridor
# 11      Volei Villena Petrer
#
#                                     Datos de contacto
# 0       670553183, 600406299, clubemevelugo@gmail.com
# 1                        Colegio Cisneros, Tenerife
# 2   clubvoleypalma@gmail.com, Estadio, Pabellón So...
# 3   635241727, presidencia@voleimanacor.club, Estadio
# 4                       Centro Insular de Deportes,
# 5             639182052, cvmelilla@gmail.com, Estadio
# 6   PM El Batán, Calle Severo Ochoa SN, 35015 - La...
# 7   659329879, direcciongeneral@rioduerovoley.com,...
# 8            (+34) 978 62 50 76, 699645272, 978601437
# 9   950 62 07 30, 950281592, guillecarmona@almeria...
# 10  PM Benicalap Sur, Castellonet de la Conquesta ...
# 11  Pabellón Gedeón e Isaias Guardiola Rico, Aveni...

# %%
with open('pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
from sqlalchemy import create_engine

# Establece una conexión para crear la base de datos
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)

# Crea un motor para la base de datos FenixClub
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/FenixClub')

# %%
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/FenixClub')

# %%
datos.to_sql('Equipos', con=engine, if_exists='replace', index=False)

# %%
datos.to_csv('Equipos.csv', index=False)
