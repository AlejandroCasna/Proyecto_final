# %%
import pandas as pd
import psycopg2 as ps
import csv
from sqlalchemy import create_engine

# %%
q = pd.read_csv('../../data/2023-2024/jugadores.csv', encoding='utf-8')
w = pd.read_csv('../../data/2022-2023/jugadores.csv', encoding='utf-8')
e = pd.read_csv('../../data/2021-2022/jugadores.csv', encoding='utf-8')
s = pd.read_csv('../../data/2020-2021/jugadores.csv', encoding='utf-8')
r = pd.read_csv('../../data/2019-2020/jugadores.csv', encoding='utf-8')

jugadores = pd.concat([q, w, e, s, r], ignore_index=True)
jugadores
# Out:
#      Dorsal                                Nombre        Posicion  Altura  \
# 0         2                Paradela Corton Miguel          Libero     0.0
# 1         3                 Bouza Ferreiro Victor        Receptor     0.0
# 2         4                     Linares Jose Luis         Opuesto     0.0
# 3         5              Barrasa Portomene Samuel          Libero     0.0
# 4         6                 Edward Batalla Dexter     Colocador/a     0.0
# ..      ...                                   ...             ...     ...
# 882      13          Calzon Algaba Francisco Jose  Middle-blocker   198.0
# 883      14                    Rojas Guevara Andy        Receptor   197.0
# 884      15                  Hoyuela Rojas Manuel     Colocador/a   171.0
# 885      17  Egusquiza Perez-Rasilla Miguel Angel     Colocador/a   195.0
# 886      21                         Cheng-Yang Wu  Middle-blocker   187.0
#
#      Ano_de_nacimiento  Alcance_en_ataque  Alcance_en_bloqueo     id_jugador  \
# ...

# %%
jugadores.to_csv('../data/Equipos.csv', index=False)

# %%
with open('../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
engine = create_engine(f'postgresql://TradeOne:{pass_}@localhost:5432/VoleyballDB')

# %%
# Utilizar to_sql para escribir el DataFrame en la base de datos
equipos.to_sql('nombre_tabla', engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\ironhack\Proyecto_final\posgresSQL\equipo_posgreSQL.ipynb Celda 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/ironhack/Proyecto_final/posgresSQL/equipo_posgreSQL.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Utilizar to_sql para escribir el DataFrame en la base de datos
# ----> <a href='vscode-notebook-cell:/c%3A/ironhack/Proyecto_final/posgresSQL/equipo_posgreSQL.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> equipos.to_sql('nombre_tabla', engine, if_exists='append', index=False)
#
# File c:\Users\Alejandro\anaconda3\ProyectoFinal\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
# ...
